# %% [markdown]
# # Conversione dei dati di PA Digitale in LD

# %%
import pandas as pd
import rdflib
import json
from IPython.display import Markdown as md
from IPython.display import JSON

# %%
from pybars import Compiler
import urllib.parse

# Funzione helper per evitare di ottenere IRI non valide
def encodeURIComponent(this,value):
    return urllib.parse.quote(value)

def extractNumeroMisura(this, value):
    ret=None
    match = re.match(r"(\d+\.\d+\.\d+)", value)

    if match:
        ret = match.group(1)

    return ret

def apply_handlebars_template(template, data):
    compiler = Compiler()
    context = {
        'encodeURIComponent': encodeURIComponent,
        'extractNumeroMisura': extractNumeroMisura
    }
    return compiler.compile(template)(data, helpers=context)

# %%
with open("srcdata/data/candidature_comuni_finanziate.json", 'r') as f:
    PADigitale_json=json.load(f)

# %% [markdown]
# Per i dati di PADigitale le ontologie di riferimento sono:
#
# * L'ontologia delle organizzazioni https://w3id.org/italia/onto/COV/
# * L'ontologia dei luoghi https://w3id.org/italia/onto/Project/

# %%
md("All'interno del file ci sono {} candidature finanziate".format(len(PADigitale_json["candidature"])))
# Out:
# All'interno del file ci sono 568 candidature finanziate

# %% [markdown]
# Il formato di partenza dei dati di PADigitale è:

# %%
JSON(PADigitale_json["candidature"][0])

# %% [markdown]
# Definiamo quindi un template per PADigitale
#
# Notare che abbiamo usato l'iterazione all'interno del template e il costrutto `#unless` che permette di generare un JSON-LD valido.

# %%
PADigitale_template="""
{
    "@context": {
    "l0": "https://w3id.org/italia/onto/l0/",
    "CLV": "https://w3id.org/italia/onto/CLV/",
    "COV": "https://w3id.org/italia/onto/COV/",
    "PRJ": "https://w3id.org/italia/onto/Project/"
    },
    "@graph": [
        {{#each .candidature}}
        {
        "@type": "PRJ:PublicInvestmentProject",
        "@id": "https://w3id.org/italia/data/PublicInvestmentProject/{{encodeURIComponent codice_cup}}",

        "PRJ:uniqueProjectCodeValue": "{{codice_cup}}",
        "PRJ:projectTitle": "Progetto {{codice_cup}} per il comune {{codice_ipa}} relativo all'avviso {{avviso}}",
        "PRJ:hasCall": {
            "@id":"https://w3id.org/italia/data/Call/{{encodeURIComponent avviso}}",
            "l0:name": "{{avviso}}",
            "@type": "PRJ:Call"
            },
        "PRJ:hasProgramme": {
            "@type": "PRJ:Programme",
            "l0:name": "PNRR"
            }
        }
        {{#unless @last}},{{/unless}}
        {{/each}}
    ]
}
"""

# %%
# Trasformazione di JSON in JSON-LD

PADigitale_json_ld = apply_handlebars_template(PADigitale_template,PADigitale_json)

# %%
with open ("LD/json-ld/candidature_comuni_finanziate-ld.json", "w+") as f:
    f.write(PADigitale_json_ld)

# %%
print(PADigitale_json_ld)
# Out:
# {
#     "@context": {
#     "l0": "https://w3id.org/italia/onto/l0/",
#     "CLV": "https://w3id.org/italia/onto/CLV/",
#     "COV": "https://w3id.org/italia/onto/COV/",
#     "PRJ": "https://w3id.org/italia/onto/Project/"
#     },
#     "@graph": [
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D81F22000260006",
#
#         "PRJ:uniqueProjectCodeValue": "D81F22000260006",
#         "PRJ:projectTitle": "Progetto D81F22000260006 per il comune c_g039 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E31F22000170006",
#
#         "PRJ:uniqueProjectCodeValue": "E31F22000170006",
#         "PRJ:projectTitle": "Progetto E31F22000170006 per il comune c_a271 relativo all'avviso 1.4.3 - pagoPA - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20pagoPA%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - pagoPA - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/G91F22000010006",
#
#         "PRJ:uniqueProjectCodeValue": "G91F22000010006",
#         "PRJ:projectTitle": "Progetto G91F22000010006 per il comune c_c800 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F41F22000020006",
#
#         "PRJ:uniqueProjectCodeValue": "F41F22000020006",
#         "PRJ:projectTitle": "Progetto F41F22000020006 per il comune c_f156 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I51F22000070006",
#
#         "PRJ:uniqueProjectCodeValue": "I51F22000070006",
#         "PRJ:projectTitle": "Progetto I51F22000070006 per il comune c_h645 relativo all'avviso 1.4.3 - app IO - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20app%20IO%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - app IO - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E21F22000700006",
#
#         "PRJ:uniqueProjectCodeValue": "E21F22000700006",
#         "PRJ:projectTitle": "Progetto E21F22000700006 per il comune c_e270 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E21F22001920006",
#
#         "PRJ:uniqueProjectCodeValue": "E21F22001920006",
#         "PRJ:projectTitle": "Progetto E21F22001920006 per il comune c_e270 relativo all'avviso 1.4.3 - app IO - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20app%20IO%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - app IO - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F81C22000710006",
#
#         "PRJ:uniqueProjectCodeValue": "F81C22000710006",
#         "PRJ:projectTitle": "Progetto F81C22000710006 per il comune c_h769 relativo all'avviso 1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.2%20Abilitazione%20al%20cloud%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F81F22001360006",
#
#         "PRJ:uniqueProjectCodeValue": "F81F22001360006",
#         "PRJ:projectTitle": "Progetto F81F22001360006 per il comune c_h769 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F81F22001030006",
#
#         "PRJ:uniqueProjectCodeValue": "F81F22001030006",
#         "PRJ:projectTitle": "Progetto F81F22001030006 per il comune c_h769 relativo all'avviso 1.4.3 - pagoPA - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20pagoPA%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - pagoPA - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F81F22002470006",
#
#         "PRJ:uniqueProjectCodeValue": "F81F22002470006",
#         "PRJ:projectTitle": "Progetto F81F22002470006 per il comune c_h769 relativo all'avviso 1.4.3 - app IO - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20app%20IO%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - app IO - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J61F22001020006",
#
#         "PRJ:uniqueProjectCodeValue": "J61F22001020006",
#         "PRJ:projectTitle": "Progetto J61F22001020006 per il comune c_f005 relativo all'avviso 1.4.3 - app IO - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20app%20IO%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - app IO - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H91F22000270007",
#
#         "PRJ:uniqueProjectCodeValue": "H91F22000270007",
#         "PRJ:projectTitle": "Progetto H91F22000270007 per il comune c_d123 relativo all'avviso 1.4.3 - app IO - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20app%20IO%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - app IO - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C61F22000090006",
#
#         "PRJ:uniqueProjectCodeValue": "C61F22000090006",
#         "PRJ:projectTitle": "Progetto C61F22000090006 per il comune c_f851 relativo all'avviso 1.4.3 - app IO - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20app%20IO%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - app IO - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J31C22000600006",
#
#         "PRJ:uniqueProjectCodeValue": "J31C22000600006",
#         "PRJ:projectTitle": "Progetto J31C22000600006 per il comune c_a413 relativo all'avviso 1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.2%20Abilitazione%20al%20cloud%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J31F22001240006",
#
#         "PRJ:uniqueProjectCodeValue": "J31F22001240006",
#         "PRJ:projectTitle": "Progetto J31F22001240006 per il comune c_e500 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J31F22002120006",
#
#         "PRJ:uniqueProjectCodeValue": "J31F22002120006",
#         "PRJ:projectTitle": "Progetto J31F22002120006 per il comune c_e500 relativo all'avviso 1.4.3 - app IO - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20app%20IO%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - app IO - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E91F22000330006",
#
#         "PRJ:uniqueProjectCodeValue": "E91F22000330006",
#         "PRJ:projectTitle": "Progetto E91F22000330006 per il comune c_h657 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D41F22000020007",
#
#         "PRJ:uniqueProjectCodeValue": "D41F22000020007",
#         "PRJ:projectTitle": "Progetto D41F22000020007 per il comune c_c618 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D41F22000690002",
#
#         "PRJ:uniqueProjectCodeValue": "D41F22000690002",
#         "PRJ:projectTitle": "Progetto D41F22000690002 per il comune c_c618 relativo all'avviso 1.4.3 - pagoPA - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20pagoPA%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - pagoPA - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H11F22000160006",
#
#         "PRJ:uniqueProjectCodeValue": "H11F22000160006",
#         "PRJ:projectTitle": "Progetto H11F22000160006 per il comune c_c052 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F41F22000240006",
#
#         "PRJ:uniqueProjectCodeValue": "F41F22000240006",
#         "PRJ:projectTitle": "Progetto F41F22000240006 per il comune c_f158 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E91F22000060006",
#
#         "PRJ:uniqueProjectCodeValue": "E91F22000060006",
#         "PRJ:projectTitle": "Progetto E91F22000060006 per il comune c_l956 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F81F22001260006",
#
#         "PRJ:uniqueProjectCodeValue": "F81F22001260006",
#         "PRJ:projectTitle": "Progetto F81F22001260006 per il comune c_b296 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E91F22000740006",
#
#         "PRJ:uniqueProjectCodeValue": "E91F22000740006",
#         "PRJ:projectTitle": "Progetto E91F22000740006 per il comune c_l956 relativo all'avviso 1.4.3 - pagoPA - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20pagoPA%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - pagoPA - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C61F22000430006",
#
#         "PRJ:uniqueProjectCodeValue": "C61F22000430006",
#         "PRJ:projectTitle": "Progetto C61F22000430006 per il comune c_f851 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F81F22000110006",
#
#         "PRJ:uniqueProjectCodeValue": "F81F22000110006",
#         "PRJ:projectTitle": "Progetto F81F22000110006 per il comune c_f116 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/G91F22000020006",
#
#         "PRJ:uniqueProjectCodeValue": "G91F22000020006",
#         "PRJ:projectTitle": "Progetto G91F22000020006 per il comune c_c800 relativo all'avviso 1.4.3 - app IO - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20app%20IO%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - app IO - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F91F22000530006",
#
#         "PRJ:uniqueProjectCodeValue": "F91F22000530006",
#         "PRJ:projectTitle": "Progetto F91F22000530006 per il comune c_c815 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F41F22000940006",
#
#         "PRJ:uniqueProjectCodeValue": "F41F22000940006",
#         "PRJ:projectTitle": "Progetto F41F22000940006 per il comune c_f156 relativo all'avviso 1.4.3 - app IO - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20app%20IO%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - app IO - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I51F22000340006",
#
#         "PRJ:uniqueProjectCodeValue": "I51F22000340006",
#         "PRJ:projectTitle": "Progetto I51F22000340006 per il comune c_i699 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D81F22000400006",
#
#         "PRJ:uniqueProjectCodeValue": "D81F22000400006",
#         "PRJ:projectTitle": "Progetto D81F22000400006 per il comune c_b303 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I51F22002040006",
#
#         "PRJ:uniqueProjectCodeValue": "I51F22002040006",
#         "PRJ:projectTitle": "Progetto I51F22002040006 per il comune c_i699 relativo all'avviso 1.4.3 - pagoPA - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20pagoPA%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - pagoPA - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I51C22000360006",
#
#         "PRJ:uniqueProjectCodeValue": "I51C22000360006",
#         "PRJ:projectTitle": "Progetto I51C22000360006 per il comune c_i699 relativo all'avviso 1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.2%20Abilitazione%20al%20cloud%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J41F22001980006",
#
#         "PRJ:uniqueProjectCodeValue": "J41F22001980006",
#         "PRJ:projectTitle": "Progetto J41F22001980006 per il comune c_e562 relativo all'avviso 1.4.3 - pagoPA - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20pagoPA%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - pagoPA - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E81C22000230006",
#
#         "PRJ:uniqueProjectCodeValue": "E81C22000230006",
#         "PRJ:projectTitle": "Progetto E81C22000230006 per il comune c_e591 relativo all'avviso 1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.2%20Abilitazione%20al%20cloud%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F41F22000530006",
#
#         "PRJ:uniqueProjectCodeValue": "F41F22000530006",
#         "PRJ:projectTitle": "Progetto F41F22000530006 per il comune c_f156 relativo all'avviso 1.4.3 - pagoPA - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20pagoPA%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - pagoPA - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D41C22000140006",
#
#         "PRJ:uniqueProjectCodeValue": "D41C22000140006",
#         "PRJ:projectTitle": "Progetto D41C22000140006 per il comune c_a473 relativo all'avviso 1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.2%20Abilitazione%20al%20cloud%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J51F22000270006",
#
#         "PRJ:uniqueProjectCodeValue": "J51F22000270006",
#         "PRJ:projectTitle": "Progetto J51F22000270006 per il comune c_c540 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F81F22000770006",
#
#         "PRJ:uniqueProjectCodeValue": "F81F22000770006",
#         "PRJ:projectTitle": "Progetto F81F22000770006 per il comune c_h769 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J21F22000460006",
#
#         "PRJ:uniqueProjectCodeValue": "J21F22000460006",
#         "PRJ:projectTitle": "Progetto J21F22000460006 per il comune c_c312 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H91F22000430006",
#
#         "PRJ:uniqueProjectCodeValue": "H91F22000430006",
#         "PRJ:projectTitle": "Progetto H91F22000430006 per il comune c_d123 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I31C22000120006",
#
#         "PRJ:uniqueProjectCodeValue": "I31C22000120006",
#         "PRJ:projectTitle": "Progetto I31C22000120006 per il comune c_m102 relativo all'avviso 1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.2%20Abilitazione%20al%20cloud%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J31F22000630006",
#
#         "PRJ:uniqueProjectCodeValue": "J31F22000630006",
#         "PRJ:projectTitle": "Progetto J31F22000630006 per il comune c_h683 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F21F22000370006",
#
#         "PRJ:uniqueProjectCodeValue": "F21F22000370006",
#         "PRJ:projectTitle": "Progetto F21F22000370006 per il comune c_f729 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/G41F22001120006",
#
#         "PRJ:uniqueProjectCodeValue": "G41F22001120006",
#         "PRJ:projectTitle": "Progetto G41F22001120006 per il comune c_d286 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H51F22000980006",
#
#         "PRJ:uniqueProjectCodeValue": "H51F22000980006",
#         "PRJ:projectTitle": "Progetto H51F22000980006 per il comune c_a714 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H51F22000180006",
#
#         "PRJ:uniqueProjectCodeValue": "H51F22000180006",
#         "PRJ:projectTitle": "Progetto H51F22000180006 per il comune c_a714 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H51F22001090006",
#
#         "PRJ:uniqueProjectCodeValue": "H51F22001090006",
#         "PRJ:projectTitle": "Progetto H51F22001090006 per il comune c_a714 relativo all'avviso 1.4.3 - app IO - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20app%20IO%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - app IO - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E31F20000130005",
#
#         "PRJ:uniqueProjectCodeValue": "E31F20000130005",
#         "PRJ:projectTitle": "Progetto E31F20000130005 per il comune c_a271 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E11F22001470006",
#
#         "PRJ:uniqueProjectCodeValue": "E11F22001470006",
#         "PRJ:projectTitle": "Progetto E11F22001470006 per il comune c_e632 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D11F22000540006",
#
#         "PRJ:uniqueProjectCodeValue": "D11F22000540006",
#         "PRJ:projectTitle": "Progetto D11F22000540006 per il comune c_h644 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E41F22000080006",
#
#         "PRJ:uniqueProjectCodeValue": "E41F22000080006",
#         "PRJ:projectTitle": "Progetto E41F22000080006 per il comune c_f280 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/G51F22000260006",
#
#         "PRJ:uniqueProjectCodeValue": "G51F22000260006",
#         "PRJ:projectTitle": "Progetto G51F22000260006 per il comune c_b729 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H11C22000040006",
#
#         "PRJ:uniqueProjectCodeValue": "H11C22000040006",
#         "PRJ:projectTitle": "Progetto H11C22000040006 per il comune c_c052 relativo all'avviso 1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.2%20Abilitazione%20al%20cloud%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H11F22000790006",
#
#         "PRJ:uniqueProjectCodeValue": "H11F22000790006",
#         "PRJ:projectTitle": "Progetto H11F22000790006 per il comune c_c052 relativo all'avviso 1.4.3 - pagoPA - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20pagoPA%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - pagoPA - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E91C22000050006",
#
#         "PRJ:uniqueProjectCodeValue": "E91C22000050006",
#         "PRJ:projectTitle": "Progetto E91C22000050006 per il comune c_l956 relativo all'avviso 1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.2%20Abilitazione%20al%20cloud%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E91F22000320006",
#
#         "PRJ:uniqueProjectCodeValue": "E91F22000320006",
#         "PRJ:projectTitle": "Progetto E91F22000320006 per il comune c_l956 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H71F22000940006",
#
#         "PRJ:uniqueProjectCodeValue": "H71F22000940006",
#         "PRJ:projectTitle": "Progetto H71F22000940006 per il comune c_a220 relativo all'avviso 1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.4%20Adozione%20SPID%20CIE%20%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.4 Adozione SPID CIE  - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H71F22000950006",
#
#         "PRJ:uniqueProjectCodeValue": "H71F22000950006",
#         "PRJ:projectTitle": "Progetto H71F22000950006 per il comune c_a220 relativo all'avviso 1.4.3 - app IO - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20app%20IO%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - app IO - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H71F22000330006",
#
#         "PRJ:uniqueProjectCodeValue": "H71F22000330006",
#         "PRJ:projectTitle": "Progetto H71F22000330006 per il comune c_a220 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D41C22000040002",
#
#         "PRJ:uniqueProjectCodeValue": "D41C22000040002",
#         "PRJ:projectTitle": "Progetto D41C22000040002 per il comune c_c618 relativo all'avviso 1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.2%20Abilitazione%20al%20cloud%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.2 Abilitazione al cloud - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J21F22000380006",
#
#         "PRJ:uniqueProjectCodeValue": "J21F22000380006",
#         "PRJ:projectTitle": "Progetto J21F22000380006 per il comune c_b240 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D41F22001050002",
#
#         "PRJ:uniqueProjectCodeValue": "D41F22001050002",
#         "PRJ:projectTitle": "Progetto D41F22001050002 per il comune c_c618 relativo all'avviso 1.4.3 - app IO - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20app%20IO%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.3 - app IO - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E31F22001070006",
#
#         "PRJ:uniqueProjectCodeValue": "E31F22001070006",
# ...
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/B11F22000590006",
#
#         "PRJ:uniqueProjectCodeValue": "B11F22000590006",
#         "PRJ:projectTitle": "Progetto B11F22000590006 per il comune c_l118 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F81F22001400006",
#
#         "PRJ:uniqueProjectCodeValue": "F81F22001400006",
#         "PRJ:projectTitle": "Progetto F81F22001400006 per il comune c_f187 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D71F22001420006",
#
#         "PRJ:uniqueProjectCodeValue": "D71F22001420006",
#         "PRJ:projectTitle": "Progetto D71F22001420006 per il comune c_m113 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Aprile%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Aprile 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I41C22001270006",
#
#         "PRJ:uniqueProjectCodeValue": "I41C22001270006",
#         "PRJ:projectTitle": "Progetto I41C22001270006 per il comune c_g148 relativo all'avviso 1.2 Abilitazione al Cloud - Comuni - Luglio 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.2%20Abilitazione%20al%20Cloud%20-%20Comuni%20-%20Luglio%202022",
#             "l0:name": "1.2 Abilitazione al Cloud - Comuni - Luglio 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/B41C22001490006",
#
#         "PRJ:uniqueProjectCodeValue": "B41C22001490006",
#         "PRJ:projectTitle": "Progetto B41C22001490006 per il comune c_g173 relativo all'avviso 1.2 Abilitazione al Cloud - Comuni - Luglio 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.2%20Abilitazione%20al%20Cloud%20-%20Comuni%20-%20Luglio%202022",
#             "l0:name": "1.2 Abilitazione al Cloud - Comuni - Luglio 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J51F22002730006",
#
#         "PRJ:uniqueProjectCodeValue": "J51F22002730006",
#         "PRJ:projectTitle": "Progetto J51F22002730006 per il comune c_f999 relativo all'avviso 1.4.5 &#x27;Piattaforma Notifiche Digitali&#x27; Comuni (Settembre 2022)",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.5%20%27Piattaforma%20Notifiche%20Digitali%27%20Comuni%20%28Settembre%202022%29",
#             "l0:name": "1.4.5 &#x27;Piattaforma Notifiche Digitali&#x27; Comuni (Settembre 2022)",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/G31F22003130006",
#
#         "PRJ:uniqueProjectCodeValue": "G31F22003130006",
#         "PRJ:projectTitle": "Progetto G31F22003130006 per il comune c_e738 relativo all'avviso 1.4.5 &#x27;Piattaforma Notifiche Digitali&#x27; Comuni (Settembre 2022)",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.5%20%27Piattaforma%20Notifiche%20Digitali%27%20Comuni%20%28Settembre%202022%29",
#             "l0:name": "1.4.5 &#x27;Piattaforma Notifiche Digitali&#x27; Comuni (Settembre 2022)",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D91F22003530006",
#
#         "PRJ:uniqueProjectCodeValue": "D91F22003530006",
#         "PRJ:projectTitle": "Progetto D91F22003530006 per il comune c_c118 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Settembre 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Settembre%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Settembre 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I61F22003460006",
#
#         "PRJ:uniqueProjectCodeValue": "I61F22003460006",
#         "PRJ:projectTitle": "Progetto I61F22003460006 per il comune c_e897 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Settembre 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Settembre%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Settembre 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H71F22003480006",
#
#         "PRJ:uniqueProjectCodeValue": "H71F22003480006",
#         "PRJ:projectTitle": "Progetto H71F22003480006 per il comune c_l823 relativo all'avviso 1.4.3 - pagoPA - Comuni - Settembre 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20pagoPA%20-%20Comuni%20-%20Settembre%202022",
#             "l0:name": "1.4.3 - pagoPA - Comuni - Settembre 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H71F22003490006",
#
#         "PRJ:uniqueProjectCodeValue": "H71F22003490006",
#         "PRJ:projectTitle": "Progetto H71F22003490006 per il comune c_l823 relativo all'avviso 1.4.3 - app IO - Comuni - Settembre 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20app%20IO%20-%20Comuni%20-%20Settembre%202022",
#             "l0:name": "1.4.3 - app IO - Comuni - Settembre 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C91F22004350006",
#
#         "PRJ:uniqueProjectCodeValue": "C91F22004350006",
#         "PRJ:projectTitle": "Progetto C91F22004350006 per il comune c_d200 relativo all'avviso 1.4.5 &#x27;Piattaforma Notifiche Digitali&#x27; Comuni (Settembre 2022)",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.5%20%27Piattaforma%20Notifiche%20Digitali%27%20Comuni%20%28Settembre%202022%29",
#             "l0:name": "1.4.5 &#x27;Piattaforma Notifiche Digitali&#x27; Comuni (Settembre 2022)",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H11F22000790006",
#
#         "PRJ:uniqueProjectCodeValue": "H11F22000790006",
#         "PRJ:projectTitle": "Progetto H11F22000790006 per il comune c_c052 relativo all'avviso 1.4.3 - pagoPA - Comuni - Settembre 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20pagoPA%20-%20Comuni%20-%20Settembre%202022",
#             "l0:name": "1.4.3 - pagoPA - Comuni - Settembre 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/B41F22002040006",
#
#         "PRJ:uniqueProjectCodeValue": "B41F22002040006",
#         "PRJ:projectTitle": "Progetto B41F22002040006 per il comune c_e730 relativo all'avviso 1.4.3 - pagoPA - Comuni - Settembre 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20pagoPA%20-%20Comuni%20-%20Settembre%202022",
#             "l0:name": "1.4.3 - pagoPA - Comuni - Settembre 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E51F22002050006",
#
#         "PRJ:uniqueProjectCodeValue": "E51F22002050006",
#         "PRJ:projectTitle": "Progetto E51F22002050006 per il comune c_f029 relativo all'avviso 1.4.3 - pagoPA - Comuni - Settembre 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20pagoPA%20-%20Comuni%20-%20Settembre%202022",
#             "l0:name": "1.4.3 - pagoPA - Comuni - Settembre 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/G51C22001410006",
#
#         "PRJ:uniqueProjectCodeValue": "G51C22001410006",
#         "PRJ:projectTitle": "Progetto G51C22001410006 per il comune c_b729 relativo all'avviso 1.2 Abilitazione al Cloud - Comuni - Luglio 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.2%20Abilitazione%20al%20Cloud%20-%20Comuni%20-%20Luglio%202022",
#             "l0:name": "1.2 Abilitazione al Cloud - Comuni - Luglio 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J51F22006490006",
#
#         "PRJ:uniqueProjectCodeValue": "J51F22006490006",
#         "PRJ:projectTitle": "Progetto J51F22006490006 per il comune c_l734 relativo all'avviso 1.3.1 Piattaforma Digitale Nazionale Dati - Comuni Ottobre 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.3.1%20Piattaforma%20Digitale%20Nazionale%20Dati%20-%20Comuni%20Ottobre%202022",
#             "l0:name": "1.3.1 Piattaforma Digitale Nazionale Dati - Comuni Ottobre 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F51F22008880006",
#
#         "PRJ:uniqueProjectCodeValue": "F51F22008880006",
#         "PRJ:projectTitle": "Progetto F51F22008880006 per il comune c_l736 relativo all'avviso 1.3.1 Piattaforma Digitale Nazionale Dati - Comuni Ottobre 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.3.1%20Piattaforma%20Digitale%20Nazionale%20Dati%20-%20Comuni%20Ottobre%202022",
#             "l0:name": "1.3.1 Piattaforma Digitale Nazionale Dati - Comuni Ottobre 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H11F22000790006",
#
#         "PRJ:uniqueProjectCodeValue": "H11F22000790006",
#         "PRJ:projectTitle": "Progetto H11F22000790006 per il comune c_c052 relativo all'avviso 1.4.3 - pagoPA - Comuni - maggio 2023",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.3%20-%20pagoPA%20-%20Comuni%20-%20maggio%202023",
#             "l0:name": "1.4.3 - pagoPA - Comuni - maggio 2023",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E61F22003680006",
#
#         "PRJ:uniqueProjectCodeValue": "E61F22003680006",
#         "PRJ:projectTitle": "Progetto E61F22003680006 per il comune c_h647 relativo all'avviso 1.4.1 Esperienza del Cittadino - Comuni - Settembre 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.4.1%20Esperienza%20del%20Cittadino%20-%20Comuni%20-%20Settembre%202022",
#             "l0:name": "1.4.1 Esperienza del Cittadino - Comuni - Settembre 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F41C22000220006",
#
#         "PRJ:uniqueProjectCodeValue": "F41C22000220006",
#         "PRJ:projectTitle": "Progetto F41C22000220006 per il comune c_c556 relativo all'avviso 1.2 Abilitazione al Cloud - Comuni - Luglio 2022",
#         "PRJ:hasCall": {
#             "@id":"https://w3id.org/italia/data/Call/1.2%20Abilitazione%20al%20Cloud%20-%20Comuni%20-%20Luglio%202022",
#             "l0:name": "1.2 Abilitazione al Cloud - Comuni - Luglio 2022",
#             "@type": "PRJ:Call"
#             },
#         "PRJ:hasProgramme": {
#             "@type": "PRJ:Programme",
#             "l0:name": "PNRR"
#             }
#         }
#
#     ]
# }

# %%
PADigitale_g = rdflib.Graph()
PADigitale_g.parse(data=PADigitale_json_ld,format="json-ld");

# %%
query="""
SELECT (COUNT(DISTINCT ?CUP) as ?num_CUP) 
WHERE {
    # ?prj a PRJ:PublicInvestmentProject;
    PRJ:uniqueProjectCodeValue ?CUP
}
"""

res=opencup_g.query(query)

for row in res:
    print(row)
# Out:
# (rdflib.term.Literal('538', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# Come si vede, i CUP sono in numero inferiore, in quanto ve ne sono di duplicati all'interno del file.

# %% [markdown]
# Esempio di query: qual è il totale di costo dei progetti per ciascun ente?

# %%
query="""
SELECT ?funder (SUM(?totalCost) AS ?funderTotalCost)
WHERE {
    # ?prj a PRJ:PublicInvestmentProject;
    PRJ:projectFunder ?funder;
    PRJ:projectTotalCost ?totalCost.
}
GROUP BY ?funder
ORDER BY DESC(?funderTotalCost)
"""

res=opencup_g.query(query)

for row in res:
    print(row)
# Out:
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00339370272'), rdflib.term.Literal('7127677', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80015010723'), rdflib.term.Literal('4858680', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00297110389'), rdflib.term.Literal('1692369', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00080270838'), rdflib.term.Literal('1547897', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00229080338'), rdflib.term.Literal('1479027', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00304260409'), rdflib.term.Literal('1031574', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/91008330903'), rdflib.term.Literal('965270', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00360140446'), rdflib.term.Literal('752741', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00355870221'), rdflib.term.Literal('719758', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80001190877'), rdflib.term.Literal('679976', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00252240262'), rdflib.term.Literal('665866', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00834770158'), rdflib.term.Literal('643416', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00268250230'), rdflib.term.Literal('643416', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00221940364'), rdflib.term.Literal('616095', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00351040423'), rdflib.term.Literal('614609', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00152550208'), rdflib.term.Literal('600427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00385230545'), rdflib.term.Literal('587589', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80000330656'), rdflib.term.Literal('585323', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00189800204'), rdflib.term.Literal('564156', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00516890241'), rdflib.term.Literal('554781', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01063800153'), rdflib.term.Literal('533050', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82002490264'), rdflib.term.Literal('527756', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00211160114'), rdflib.term.Literal('527308', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00097020598'), rdflib.term.Literal('516323', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00893240150'), rdflib.term.Literal('419124', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80007310263'), rdflib.term.Literal('419124', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00172960361'), rdflib.term.Literal('407813', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00372530162'), rdflib.term.Literal('404159', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/85001870188'), rdflib.term.Literal('402506', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00602060139'), rdflib.term.Literal('392385', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01639920154'), rdflib.term.Literal('376098', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00543170377'), rdflib.term.Literal('371413', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82005730161'), rdflib.term.Literal('371305', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00426650131'), rdflib.term.Literal('365895', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82001930385'), rdflib.term.Literal('357000', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82002550398'), rdflib.term.Literal('355151', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80008790174'), rdflib.term.Literal('346280', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00263530123'), rdflib.term.Literal('344902', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00223680125'), rdflib.term.Literal('344159', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01495680157'), rdflib.term.Literal('344159', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00606990174'), rdflib.term.Literal('343513', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/83005620154'), rdflib.term.Literal('342984', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00115070336'), rdflib.term.Literal('341745', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80004190593'), rdflib.term.Literal('333788', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/81000450643'), rdflib.term.Literal('328422', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01493120586'), rdflib.term.Literal('328160', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00794470377'), rdflib.term.Literal('328160', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00493110928'), rdflib.term.Literal('323815', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/87003290159'), rdflib.term.Literal('320791', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00168480242'), rdflib.term.Literal('318485', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80004870921'), rdflib.term.Literal('312084', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80001830936'), rdflib.term.Literal('309815', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00232420331'), rdflib.term.Literal('309815', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01315140150'), rdflib.term.Literal('304956', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80004000925'), rdflib.term.Literal('294198', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00314810367'), rdflib.term.Literal('286900', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/03482920158'), rdflib.term.Literal('280932', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00870790151'), rdflib.term.Literal('280932', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/03519480150'), rdflib.term.Literal('280932', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/83001590724'), rdflib.term.Literal('280932', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00170360341'), rdflib.term.Literal('277226', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/04203260247'), rdflib.term.Literal('277226', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00162600506'), rdflib.term.Literal('277226', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/84001170228'), rdflib.term.Literal('277226', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80101990150'), rdflib.term.Literal('277226', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00366960540'), rdflib.term.Literal('277226', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82001410164'), rdflib.term.Literal('277226', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01556360152'), rdflib.term.Literal('277226', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80014070223'), rdflib.term.Literal('260534', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00451340178'), rdflib.term.Literal('259144', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80007710264'), rdflib.term.Literal('253029', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/02866100155'), rdflib.term.Literal('252118', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01329160483'), rdflib.term.Literal('252118', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00297910796'), rdflib.term.Literal('248621', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01743420158'), rdflib.term.Literal('246824', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00311560361'), rdflib.term.Literal('225317', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00108690470'), rdflib.term.Literal('222714', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80011350750'), rdflib.term.Literal('215125', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00391260403'), rdflib.term.Literal('208167', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00179650221'), rdflib.term.Literal('205253', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00631280138'), rdflib.term.Literal('205099', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/84003870163'), rdflib.term.Literal('204639', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00254640121'), rdflib.term.Literal('200001', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00148580392'), rdflib.term.Literal('197003', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00202100392'), rdflib.term.Literal('197003', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00203130398'), rdflib.term.Literal('196146', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00343220398'), rdflib.term.Literal('196146', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00257850396'), rdflib.term.Literal('196146', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00237070362'), rdflib.term.Literal('192728', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00662760362'), rdflib.term.Literal('192728', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00242500395'), rdflib.term.Literal('191861', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82002850137'), rdflib.term.Literal('191138', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00308950096'), rdflib.term.Literal('187823', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00316390228'), rdflib.term.Literal('187823', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00224340331'), rdflib.term.Literal('174925', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01175480159'), rdflib.term.Literal('173646', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/85000870221'), rdflib.term.Literal('171731', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00339190225'), rdflib.term.Literal('169500', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00215780339'), rdflib.term.Literal('166567', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00533680658'), rdflib.term.Literal('164496', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00183800341'), rdflib.term.Literal('163466', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/02030880153'), rdflib.term.Literal('162545', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/84006890481'), rdflib.term.Literal('162545', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00428360242'), rdflib.term.Literal('158964', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/03611890157'), rdflib.term.Literal('157819', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82005750904'), rdflib.term.Literal('157819', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00686230368'), rdflib.term.Literal('155688', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00614510485'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00251880167'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/86002050580'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00518490727'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00502010655'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00252280128'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/02423810205'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/83000110433'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00215920349'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01310860489'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/81001030204'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/02032910156'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82002570263'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/02613570429'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/83000670204'), rdflib.term.Literal('155234', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/02938070154'), rdflib.term.Literal('154581', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00286650502'), rdflib.term.Literal('152750', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80010610758'), rdflib.term.Literal('150496', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00534310248'), rdflib.term.Literal('149854', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00341200095'), rdflib.term.Literal('147994', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00547910653'), rdflib.term.Literal('147913', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/84503700159'), rdflib.term.Literal('145064', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00478370182'), rdflib.term.Literal('142336', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00183970508'), rdflib.term.Literal('142336', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/83000370508'), rdflib.term.Literal('140263', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00240880161'), rdflib.term.Literal('132623', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/81002210862'), rdflib.term.Literal('132325', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00624040135'), rdflib.term.Literal('129050', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00137850145'), rdflib.term.Literal('127349', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00720170166'), rdflib.term.Literal('126064', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82002930285'), rdflib.term.Literal('123630', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00650920168'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/81001510551'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00135420099'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/02843410156'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/02540250202'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01068100153'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00299140194'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/02401940222'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82000610152'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00135350197'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00223660127'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00852210178'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00417080132'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00177340197'), rdflib.term.Literal('121992', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00073930950'), rdflib.term.Literal('118284', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80007510227'), rdflib.term.Literal('118124', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00249830225'), rdflib.term.Literal('115064', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/81000730309'), rdflib.term.Literal('114516', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00322400342'), rdflib.term.Literal('105354', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00486670268'), rdflib.term.Literal('104128', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00218780393'), rdflib.term.Literal('104055', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00391420783'), rdflib.term.Literal('103069', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00349960393'), rdflib.term.Literal('102841', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00211890330'), rdflib.term.Literal('101208', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80095950152'), rdflib.term.Literal('101044', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00577360241'), rdflib.term.Literal('99025', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00232410332'), rdflib.term.Literal('96661', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00313290389'), rdflib.term.Literal('95346', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00578180655'), rdflib.term.Literal('93922', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/03396710125'), rdflib.term.Literal('90407', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00215930348'), rdflib.term.Literal('84944', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/02147150227'), rdflib.term.Literal('83044', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00559980123'), rdflib.term.Literal('81458', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80010190306'), rdflib.term.Literal('79922', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00369340229'), rdflib.term.Literal('79922', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80024950166'), rdflib.term.Literal('79922', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00642650139'), rdflib.term.Literal('79922', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82002220620'), rdflib.term.Literal('79922', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00356330795'), rdflib.term.Literal('79922', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/03946010158'), rdflib.term.Literal('79922', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00400660445'), rdflib.term.Literal('79000', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00302640198'), rdflib.term.Literal('77897', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/81001410091'), rdflib.term.Literal('77897', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00453990178'), rdflib.term.Literal('69973', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00720160167'), rdflib.term.Literal('67767', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00152150223'), rdflib.term.Literal('62690', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/83000830758'), rdflib.term.Literal('61427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/03614850158'), rdflib.term.Literal('60301', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00220600407'), rdflib.term.Literal('59966', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00089700082'), rdflib.term.Literal('59966', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00374900165'), rdflib.term.Literal('57599', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00285750220'), rdflib.term.Literal('57256', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/83000470308'), rdflib.term.Literal('51654', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00354730392'), rdflib.term.Literal('49455', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00271100224'), rdflib.term.Literal('47427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/02402160226'), rdflib.term.Literal('47427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80008770226'), rdflib.term.Literal('47427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00308770221'), rdflib.term.Literal('47427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00386100226'), rdflib.term.Literal('47427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00517980926'), rdflib.term.Literal('47427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00319630224'), rdflib.term.Literal('47427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00431040229'), rdflib.term.Literal('47427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00149120222'), rdflib.term.Literal('47427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00423390228'), rdflib.term.Literal('47427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/84001370182'), rdflib.term.Literal('47427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00884000720'), rdflib.term.Literal('44515', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00272300229'), rdflib.term.Literal('42824', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80013790227'), rdflib.term.Literal('42824', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/81001190222'), rdflib.term.Literal('38237', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80005250222'), rdflib.term.Literal('38221', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/86002610227'), rdflib.term.Literal('36674', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00273990226'), rdflib.term.Literal('36674', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00787620723'), rdflib.term.Literal('36400', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00124030222'), rdflib.term.Literal('35000', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00662780162'), rdflib.term.Literal('32589', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82000950160'), rdflib.term.Literal('32589', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00245460167'), rdflib.term.Literal('31150', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00165480096'), rdflib.term.Literal('27682', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/02254070150'), rdflib.term.Literal('20344', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00346630239'), rdflib.term.Literal('20344', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00231100512'), rdflib.term.Literal('20344', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/81000610261'), rdflib.term.Literal('20344', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00545580268'), rdflib.term.Literal('20344', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/91016750498'), rdflib.term.Literal('20154', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00252040225'), rdflib.term.Literal('19752', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00159240225'), rdflib.term.Literal('19752', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00343510228'), rdflib.term.Literal('19752', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00149130221'), rdflib.term.Literal('19752', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00308670223'), rdflib.term.Literal('19752', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80014520227'), rdflib.term.Literal('19752', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00301120226'), rdflib.term.Literal('19752', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00212680037'), rdflib.term.Literal('19711', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82003130166'), rdflib.term.Literal('11000', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82001650710'), rdflib.term.Literal('10172', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00088020086'), rdflib.term.Literal('10172', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00123600686'), rdflib.term.Literal('10172', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00118960145'), rdflib.term.Literal('5465', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/81000910224'), rdflib.term.Literal('4459', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))

# %% [markdown]
# ## Dati di IndicePA
#
# I dati di IndicePA ci occorrono, ad esempio, per collegare le partite IVA/Codici Fiscali agli enti
