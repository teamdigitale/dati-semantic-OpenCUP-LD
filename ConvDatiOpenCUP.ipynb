# %% [markdown]
# # Conversione dei dati OpenCUP in LD

# %%
import pandas as pd
import rdflib
import json
from IPython.display import Markdown as md
from IPython.display import JSON

# %%
from pybars import Compiler
import urllib.parse

# Funzione helper per evitare di ottenere IRI non valide
def encodeURIComponent(this,value):
    return urllib.parse.quote(value)

def apply_handlebars_template(template, data):
    compiler = Compiler()
    context = {
        'encodeURIComponent': encodeURIComponent
    }
    return compiler.compile(template)(data, helpers=context)

# %% [markdown]
# ### Dati di OpenCUP

# %%
with open("srcdata/data/opencup_candidature_comuni_finanziate.json", 'r') as f:
    opencup_json=json.load(f)

# %% [markdown]
# Per i dati di OpenCUP le ontologie di riferimento sono:
#
# * L'ontologia delle organizzazioni https://w3id.org/italia/onto/COV/
# * L'ontologia dei progetti https://w3id.org/italia/onto/Project/

# %%
md("All'interno del file ci sono {} progetti CUP".format(len(opencup_json["opencup"])))
# Out:
# All'interno del file ci sono 558 progetti CUP

# %% [markdown]
# Il formato di partenza dei dati di OpenCUP è:

# %%
JSON(opencup_json["opencup"][0])

# %% [markdown]
# Definiamo quindi un template che:
# * identifichi ciascun CUP con un'IRI univoca
# * riporti il titolo del progetto
# * riporti l'ente finanziatore come collegamento a un'organizzazione esterna. NB: in questo caso viene utilizzata la Partita IVA/Codice Fiscale, in quanto questo è il valore che è riportato in OpenCUP
#
# Notare che abbiamo usato l'iterazione all'interno del template e il costrutto `#unless` che permette di generare un JSON-LD valido.

# %%
opencup_template="""{
    "@context": {
    "COV": "https://w3id.org/italia/onto/COV/",
    "PRJ": "https://w3id.org/italia/onto/Project/"
    },
    "@graph": [
        {{#each .opencup}}
        {
        "@type": "PRJ:PublicInvestmentProject",
        "@id": "https://w3id.org/italia/data/PublicInvestmentProject/{{encodeURIComponent CUP}}",

        "PRJ:uniqueProjectCodeValue": "{{CUP}}",
        "PRJ:projectTitle": "{{DESCRIZIONE_SINTETICA_CUP}}",
        "PRJ:projectTotalCost": {{COSTO_PROGETTO}},
        "PRJ:projectFunder": {
            "@type":"COV:PublicOrganization",
            "@id":"https://w3id.org/italia/data/PublicOrganization/{{encodeURIComponent PIVA_CODFISCALE_SOG_TITOLARE}}",
            "COV:hasCategory": {
                "@type": "COV:PublicOrganizationCategory",
                "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/{{encodeURIComponent CATEGORIA_SOGGETTO}}"
            },
            "COV:taxCode": "{{PIVA_CODFISCALE_SOG_TITOLARE}}"
        }
        }
        {{#unless @last}},{{/unless}}
        {{/each}}
    ]
}"""

# %%
# Trasformazione di JSON in JSON-LD

opencup_json_ld = apply_handlebars_template(opencup_template,opencup_json)

# %%
with open ("LD/json-ld/opencup_candidature_comuni_finanziate-ld.json", "w+") as f:
    f.write(opencup_json_ld)

# %%
print(opencup_json_ld)
# Out:
# {
#     "@context": {
#     "COV": "https://w3id.org/italia/onto/COV/",
#     "PRJ": "https://w3id.org/italia/onto/Project/"
#     },
#     "@graph": [
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J41F22000670001",
#
#         "PRJ:uniqueProjectCodeValue": "J41F22000670001",
#         "PRJ:projectTitle": "ABILITAZIONE AL CLOUD PER LE PA LOCALI COMUNI*VIA PAPA GIOVANNI XXIII, 1*ABILITAZIONE AL CLOUD PER LE PA LOCALI COMUNI",
#         "PRJ:projectTotalCost": 121992,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00650920168",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00650920168"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E11F22003900006",
#
#         "PRJ:uniqueProjectCodeValue": "E11F22003900006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA MASSMO DE&#x27; VECCHI 17*IL SERVIZIO SERVIRÀ AD IMPLEMENTARE RICHIESTA ACCESSO AGLI ATTI, RICHIEDERE PUBBLICAZIONI MATRIMONIO, ISCRIZIONE TRASPORTO SCOLASTICO, ISCRIZIONE MENSA SCOLASTICA CON PACCHETTI ANCHE INFORMATIVI E DIGITALI SUL SITO WEB",
#         "PRJ:projectTotalCost": 79922,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00624040135",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00624040135"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D21F22003360006",
#
#         "PRJ:uniqueProjectCodeValue": "D21F22003360006",
#         "PRJ:projectTitle": "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*NOTIFICHE VIOLAZIONI AL CODICE DELLA STRADA, NOTIFICHE VIOLAZIONI EXTRA CODICE DELLA STRADA",
#         "PRJ:projectTotalCost": 59966,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00220600407",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00220600407"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I91F22001860006",
#
#         "PRJ:uniqueProjectCodeValue": "I91F22001860006",
#         "PRJ:projectTitle": "PIATTAFORMA PAGOPA*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 20568,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00203130398",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00203130398"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C41C22000320006",
#
#         "PRJ:uniqueProjectCodeValue": "C41C22000320006",
#         "PRJ:projectTitle": "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 18 SERVIZI DA MIGRARE",
#         "PRJ:projectTotalCost": 419124,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00893240150",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00893240150"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E11F22003560006",
#
#         "PRJ:uniqueProjectCodeValue": "E11F22003560006",
#         "PRJ:projectTitle": "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*NOTIFICHE VIOLAZIONI AL CODICE DELLA STRADA E NOTIFICHE VIOLAZIONI EXTRA CODICE DELLA STRADA, INTEGRAZIONE CON LA PIATTAFORMA NOTIFICHE DIGITALI.",
#         "PRJ:projectTotalCost": 32589,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00115070336",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00115070336"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/G41F22001120006",
#
#         "PRJ:uniqueProjectCodeValue": "G41F22001120006",
#         "PRJ:projectTitle": "ESTENSIONE DELLUTILIZZO DELLE PIATTAFORME NAZIONALI DI IDENTITÀ DIGITALE*TERRITORIO NAZIONALE*INTEGRAZIONE DI CIE",
#         "PRJ:projectTotalCost": 14000,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00834770158",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00834770158"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C17H22001560007",
#
#         "PRJ:uniqueProjectCodeValue": "C17H22001560007",
#         "PRJ:projectTitle": "ABILITAZIONE CLOUD*VIA IV NOVEMBRE 30*ABILITAZIONE CLOUD",
#         "PRJ:projectTotalCost": 77897,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/03611890157",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "03611890157"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C17H22001560007",
#
#         "PRJ:uniqueProjectCodeValue": "C17H22001560007",
#         "PRJ:projectTitle": "ABILITAZIONE CLOUD*VIA IV NOVEMBRE 30*ABILITAZIONE CLOUD",
#         "PRJ:projectTotalCost": 77897,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/03611890157",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "03611890157"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I61F22003460006",
#
#         "PRJ:uniqueProjectCodeValue": "I61F22003460006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA ROMA 39*ENTRAMBI",
#         "PRJ:projectTotalCost": 280932,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00189800204",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00189800204"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H81C22000520006",
#
#         "PRJ:uniqueProjectCodeValue": "H81C22000520006",
#         "PRJ:projectTitle": "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N.12 SERVIZI DA MIGRARE",
#         "PRJ:projectTotalCost": 105354,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00322400342",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00322400342"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I51F22006450006",
#
#         "PRJ:uniqueProjectCodeValue": "I51F22006450006",
#         "PRJ:projectTitle": "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE API1",
#         "PRJ:projectTotalCost": 10172,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00349960393",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00349960393"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F91C22000450006",
#
#         "PRJ:uniqueProjectCodeValue": "F91C22000450006",
#         "PRJ:projectTitle": "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 18 SERVIZI DA MIGRARE",
#         "PRJ:projectTotalCost": 414396,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/91008330903",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "91008330903"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/G61C22000090006",
#
#         "PRJ:uniqueProjectCodeValue": "G61C22000090006",
#         "PRJ:projectTitle": "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 14 SERVIZI DA MIGRARE",
#         "PRJ:projectTotalCost": 121992,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/81000450643",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "81000450643"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J31F22000510006",
#
#         "PRJ:uniqueProjectCodeValue": "J31F22000510006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIALE CENTOFIORI, 34*SITO E SEVIZI DIGITALI",
#         "PRJ:projectTotalCost": 155234,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00614510485",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00614510485"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/G91F22002430006",
#
#         "PRJ:uniqueProjectCodeValue": "G91F22002430006",
#         "PRJ:projectTitle": "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 8232,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00263530123",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00263530123"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E11F22002840006",
#
#         "PRJ:uniqueProjectCodeValue": "E11F22002840006",
#         "PRJ:projectTitle": "PIATTAFORMA PAGOPA*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 19711,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00212680037",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00212680037"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D91F22002590006",
#
#         "PRJ:uniqueProjectCodeValue": "D91F22002590006",
#         "PRJ:projectTitle": "ESTENSIONE DELLUTILIZZO DELLE PIATTAFORME NAZIONALI DI IDENTITÀ DIGITALE*TERRITORIO NAZIONALE*INTEGRAZIONE CIE",
#         "PRJ:projectTotalCost": 14000,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00577360241",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00577360241"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F41C22000040006",
#
#         "PRJ:uniqueProjectCodeValue": "F41C22000040006",
#         "PRJ:projectTitle": "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 14 SERVIZI DA MIGRARE",
#         "PRJ:projectTotalCost": 121992,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/82001930385",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "82001930385"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D51F22007060006",
#
#         "PRJ:uniqueProjectCodeValue": "D51F22007060006",
#         "PRJ:projectTitle": "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE API 1",
#         "PRJ:projectTotalCost": 10172,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00547910653",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00547910653"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C51F22003470006",
#
#         "PRJ:uniqueProjectCodeValue": "C51F22003470006",
#         "PRJ:projectTitle": "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*PIATTAFORMA NOTIFICHE DIGITALI",
#         "PRJ:projectTotalCost": 35000,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00124030222",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00124030222"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F61C22000140006",
#
#         "PRJ:uniqueProjectCodeValue": "F61C22000140006",
#         "PRJ:projectTitle": "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N 13 SERVIZI DA MIGRARE",
#         "PRJ:projectTotalCost": 77897,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00302640198",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00302640198"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H21F22000600006",
#
#         "PRJ:uniqueProjectCodeValue": "H21F22000600006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*TERRITORIO COMUNALE*SERVIZI DIGITALI PER IL CITTADINO E SITO COMUNALE",
#         "PRJ:projectTotalCost": 79922,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00391420783",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00391420783"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D91F22000440006",
#
#         "PRJ:uniqueProjectCodeValue": "D91F22000440006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA SCUDARI 20*ENTRAMBI",
#         "PRJ:projectTotalCost": 516323,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00221940364",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00221940364"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F21F22001260006",
#
#         "PRJ:uniqueProjectCodeValue": "F21F22001260006",
#         "PRJ:projectTitle": "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 10206,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00486670268",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00486670268"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C41F22003280006",
#
#         "PRJ:uniqueProjectCodeValue": "C41F22003280006",
#         "PRJ:projectTitle": "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*NOTIFICHE VIOLAZIONE CDS, NOTIFICA RISCOSSIONE TRIBUTI (CON PAGAMENTO), INTEGRAZIONE PND",
#         "PRJ:projectTotalCost": 23147,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/80010610758",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "80010610758"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D51F22011310006",
#
#         "PRJ:uniqueProjectCodeValue": "D51F22011310006",
#         "PRJ:projectTitle": "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE DI N. 2 API SUL CATALOGO API PDND DA PARTE DEI COMUNI",
#         "PRJ:projectTotalCost": 20344,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/02254070150",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "02254070150"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/B71F22000370001",
#
#         "PRJ:uniqueProjectCodeValue": "B71F22000370001",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA COMUNE DI FERRARA*SITO COMUNALE E SERVIZI DIGITALI PER IL CITTADINO (ENTRAMBI)",
#         "PRJ:projectTotalCost": 457360,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00297110389",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00297110389"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/B71F22000370001",
#
#         "PRJ:uniqueProjectCodeValue": "B71F22000370001",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA COMUNE DI FERRARA*SITO COMUNALE E SERVIZI DIGITALI PER IL CITTADINO (ENTRAMBI)",
#         "PRJ:projectTotalCost": 457360,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00297110389",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00297110389"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H11F22000160006",
#
#         "PRJ:uniqueProjectCodeValue": "H11F22000160006",
#         "PRJ:projectTitle": "ESTENSIONE DELLUTILIZZO DELLE PIATTAFORME NAZIONALI DI IDENTITÀ DIGITALE*TERRITORIO NAZIONALE*INTEGRAZIONE DI CIE",
#         "PRJ:projectTotalCost": 14000,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/01639920154",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "01639920154"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/G51F22003820006",
#
#         "PRJ:uniqueProjectCodeValue": "G51F22003820006",
#         "PRJ:projectTitle": "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*INTEGRAZIONE PIATTAFORMA PDND",
#         "PRJ:projectTotalCost": 20344,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/81000450643",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "81000450643"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C81C22005610006",
#
#         "PRJ:uniqueProjectCodeValue": "C81C22005610006",
#         "PRJ:projectTitle": "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 11 SERVIZI DA MIGRARE",
#         "PRJ:projectTotalCost": 101208,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00211890330",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00211890330"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I21C22001210006",
#
#         "PRJ:uniqueProjectCodeValue": "I21C22001210006",
#         "PRJ:projectTitle": "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 10 SERVIZI DA MIGRARE",
#         "PRJ:projectTotalCost": 57256,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00285750220",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00285750220"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D11F22003250006",
#
#         "PRJ:uniqueProjectCodeValue": "D11F22003250006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA SANT&#x27;ANTONIO 2*SITO COMUNALE E SERVIZI DIGITALI PER IL CITTADINO",
#         "PRJ:projectTotalCost": 79922,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/82005750904",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "82005750904"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E61C22001160006",
#
#         "PRJ:uniqueProjectCodeValue": "E61C22001160006",
#         "PRJ:projectTitle": "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 10 SERVIZI DA MIGRARE",
#         "PRJ:projectTotalCost": 38237,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/81001190222",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "81001190222"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E51F22007390006",
#
#         "PRJ:uniqueProjectCodeValue": "E51F22007390006",
#         "PRJ:projectTitle": "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE DI NUMERO DUE API.",
#         "PRJ:projectTotalCost": 20344,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00115070336",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00115070336"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/G51F22000330006",
#
#         "PRJ:uniqueProjectCodeValue": "G51F22000330006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*PIAZZA E. QUARANTA, N. 1*PAGARE IL CANONE PER LE LAMPADE VOTIVE, RICHIEDERE L&#x27;ACCESSO AGLI ATTI, RICHIEDERE ISCRIZIONE AL TRASPORTO SCOLASTICO, RICHIEDERE ISCRIZIONE ALLA MENSA SCOLASTICA, SITO INTERNET (PACCHETTO CITTADINO INFORMATO)",
#         "PRJ:projectTotalCost": 79922,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00533680658",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00533680658"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C51F22005010006",
#
#         "PRJ:uniqueProjectCodeValue": "C51F22005010006",
#         "PRJ:projectTitle": "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*API REST",
#         "PRJ:projectTotalCost": 20344,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00391260403",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00391260403"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/B31F22002870006",
#
#         "PRJ:uniqueProjectCodeValue": "B31F22002870006",
#         "PRJ:projectTitle": "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 4459,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/81000910224",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "81000910224"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/G31F22000580006",
#
#         "PRJ:uniqueProjectCodeValue": "G31F22000580006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIALE DON MARRTINO CHILESE 14*ADEGUAMENTO DEL SITO COMUNALE E IMPLEMENTAZIONE NUOVI SERVIZI DIGITALI (ISTANZE ON-LINE)",
#         "PRJ:projectTotalCost": 79922,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00428360242",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00428360242"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D41F22001090006",
#
#         "PRJ:uniqueProjectCodeValue": "D41F22001090006",
#         "PRJ:projectTitle": "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 13377,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00426650131",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00426650131"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I11F22000690006",
#
#         "PRJ:uniqueProjectCodeValue": "I11F22000690006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*PIAZZA VITTORIO EMANUELE II, 31*ENTRAMBI",
#         "PRJ:projectTotalCost": 155234,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00148580392",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00148580392"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I91F22001850006",
#
#         "PRJ:uniqueProjectCodeValue": "I91F22001850006",
#         "PRJ:projectTitle": "PIATTAFORMA PAGOPA*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 12747,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00349960393",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00349960393"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/I11F22001750006",
#
#         "PRJ:uniqueProjectCodeValue": "I11F22001750006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIALE FACCHINETTI 1*ENTRAMBI I SERVIZI",
#         "PRJ:projectTotalCost": 155234,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00251880167",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00251880167"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J71F22004120006",
#
#         "PRJ:uniqueProjectCodeValue": "J71F22004120006",
#         "PRJ:projectTitle": "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*PIATTAFORMA NOTIFICHE DIGITALI",
#         "PRJ:projectTotalCost": 32589,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00223680125",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00223680125"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E31F22002530006",
#
#         "PRJ:uniqueProjectCodeValue": "E31F22002530006",
#         "PRJ:projectTitle": "PIATTAFORMA PAGOPA*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 20568,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00343220398",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00343220398"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D61F22004060006",
#
#         "PRJ:uniqueProjectCodeValue": "D61F22004060006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA ALTRO*1 RICHIEDERE L&#x27;ACCESSO AGLI ATTI  2 PRESENTARE DOMANDA DI PARTECIPAZIONE A UN CONCORSO PUBBLICO 3 RICHIEDERE PERMESSO PER PARCHEGGIO INVALIDI 4 RICHIEDERE PERMESSO PER PASSO CARRABILE 5 PRESENTARE DOMANDA PER BONUS ECONOMICI 6 SITO INTERNET",
#         "PRJ:projectTotalCost": 280932,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/01315140150",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "01315140150"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/H21F22001120006",
#
#         "PRJ:uniqueProjectCodeValue": "H21F22001120006",
#         "PRJ:projectTitle": "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 17150,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00314810367",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00314810367"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C41F22000510006",
#
#         "PRJ:uniqueProjectCodeValue": "C41F22000510006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*LARGO SAN MARCO*SITO COMUNALE E SERVIZI DIGITALI PER IL CITTADINO",
#         "PRJ:projectTotalCost": 79922,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/80010610758",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "80010610758"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J91C22000850006",
#
#         "PRJ:uniqueProjectCodeValue": "J91C22000850006",
#         "PRJ:projectTitle": "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 14 SERVIZI DA MIGRARE",
#         "PRJ:projectTotalCost": 121992,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/85000870221",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "85000870221"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/B91F22003080006",
#
#         "PRJ:uniqueProjectCodeValue": "B91F22003080006",
#         "PRJ:projectTitle": "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*010102P, 010201P, 010202N",
#         "PRJ:projectTotalCost": 23147,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/80095950152",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "80095950152"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J81F22003830007",
#
#         "PRJ:uniqueProjectCodeValue": "J81F22003830007",
#         "PRJ:projectTitle": "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*ATTIVAZIONE NOTIFICHE DIGITALI",
#         "PRJ:projectTotalCost": 23147,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/84003870163",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "84003870163"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J81F22003830007",
#
#         "PRJ:uniqueProjectCodeValue": "J81F22003830007",
#         "PRJ:projectTitle": "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*ATTIVAZIONE NOTIFICHE DIGITALI",
#         "PRJ:projectTotalCost": 23147,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/84003870163",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "84003870163"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F81F22001400006",
#
#         "PRJ:uniqueProjectCodeValue": "F81F22001400006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*CORSO DEL POPOLO 17*MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE",
#         "PRJ:projectTotalCost": 155234,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/80014070223",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "80014070223"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E31F20000130005",
#
#         "PRJ:uniqueProjectCodeValue": "E31F20000130005",
# ...
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00606990174"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D41F22000290002",
#
#         "PRJ:uniqueProjectCodeValue": "D41F22000290002",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*PIAZZA MARTIRI DELLA LIBERTA&#x27; 26*ENTRAMBI",
#         "PRJ:projectTotalCost": 155234,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00606990174",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00606990174"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/D41F22000290002",
#
#         "PRJ:uniqueProjectCodeValue": "D41F22000290002",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*PIAZZA MARTIRI DELLA LIBERTA&#x27; 26*ENTRAMBI",
#         "PRJ:projectTotalCost": 155234,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00606990174",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00606990174"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C17H22001640007",
#
#         "PRJ:uniqueProjectCodeValue": "C17H22001640007",
#         "PRJ:projectTitle": "DIGITALIZZAZIONE ESPERIENZA DEL CITTADINO NEI SERVIZI PUBLBICI*VIA IV NOVEMBRE 30*SERVIZI AL CITTADINO SITO",
#         "PRJ:projectTotalCost": 79922,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/03611890157",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "03611890157"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C17H22001640007",
#
#         "PRJ:uniqueProjectCodeValue": "C17H22001640007",
#         "PRJ:projectTitle": "DIGITALIZZAZIONE ESPERIENZA DEL CITTADINO NEI SERVIZI PUBLBICI*VIA IV NOVEMBRE 30*SERVIZI AL CITTADINO SITO",
#         "PRJ:projectTotalCost": 79922,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/03611890157",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "03611890157"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F51F22010400006",
#
#         "PRJ:uniqueProjectCodeValue": "F51F22010400006",
#         "PRJ:projectTitle": "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE DI API REST",
#         "PRJ:projectTotalCost": 20344,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/81000730309",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "81000730309"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J31F22002120006",
#
#         "PRJ:uniqueProjectCodeValue": "J31F22002120006",
#         "PRJ:projectTitle": "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 3430,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00179650221",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00179650221"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F81C22001260006",
#
#         "PRJ:uniqueProjectCodeValue": "F81C22001260006",
#         "PRJ:projectTitle": "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 9 SERVIZI DA MIGRARE",
#         "PRJ:projectTotalCost": 19752,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00301120226",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00301120226"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C91F22004880006",
#
#         "PRJ:uniqueProjectCodeValue": "C91F22004880006",
#         "PRJ:projectTitle": "ESTENSIONE DELLUTILIZZO DELLE PIATTAFORME NAZIONALI DI IDENTITÀ DIGITALE*TERRITORIO NAZIONALE*INTEGRAZIONE DI SPID E CIE",
#         "PRJ:projectTotalCost": 14000,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/83000830758",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "83000830758"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F81F22001000006",
#
#         "PRJ:uniqueProjectCodeValue": "F81F22001000006",
#         "PRJ:projectTitle": "PIATTAFORMA PAGOPA*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 13712,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/80007710264",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "80007710264"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E91F22000060006",
#
#         "PRJ:uniqueProjectCodeValue": "E91F22000060006",
#         "PRJ:projectTitle": "ESTENSIONE DELLUTILIZZO DELLE PIATTAFORME NAZIONALI DI IDENTITÀ DIGITALE*TERRITORIO NAZIONALE*INTEGRAZIONE DI SPID E CIE",
#         "PRJ:projectTotalCost": 14000,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00602060139",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00602060139"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J11F22000360006",
#
#         "PRJ:uniqueProjectCodeValue": "J11F22000360006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*PIAZZA DELLA VITTORIA 3*ENTRAMBI",
#         "PRJ:projectTotalCost": 79922,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/03946010158",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "03946010158"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F41F22000240006",
#
#         "PRJ:uniqueProjectCodeValue": "F41F22000240006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA PIAZZA UNIONE EUROPEA*SITO ISTITUZIONALE E SERVIZI DIGITALI",
#         "PRJ:projectTotalCost": 516323,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00080270838",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00080270838"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/C61F22000630006",
#
#         "PRJ:uniqueProjectCodeValue": "C61F22000630006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA ROMA 37*SITO INTERNET COMUNALE E SERVIZI DIGITALI PER IL CITTADINO",
#         "PRJ:projectTotalCost": 79922,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00286650502",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00286650502"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E61F22003680006",
#
#         "PRJ:uniqueProjectCodeValue": "E61F22003680006",
#         "PRJ:projectTitle": "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*PIAZZA DEL COMUNE 1*SERVIZI DIGITALI PER IL CITTADINO",
#         "PRJ:projectTotalCost": 155234,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/80004190593",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "80004190593"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/F81F22004400006",
#
#         "PRJ:uniqueProjectCodeValue": "F81F22004400006",
#         "PRJ:projectTitle": "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*NOTIFICHE VIOLAZIONI EXTRA CODICE DELLA STRADA",
#         "PRJ:projectTotalCost": 59966,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00360140446",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00360140446"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/E91F22001770006",
#
#         "PRJ:uniqueProjectCodeValue": "E91F22001770006",
#         "PRJ:projectTitle": "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 8748,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00215780339",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00215780339"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/J11F22000910006",
#
#         "PRJ:uniqueProjectCodeValue": "J11F22000910006",
#         "PRJ:projectTitle": "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 36400,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/00172960361",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "00172960361"
#         }
#         }
#         ,
#         {
#         "@type": "PRJ:PublicInvestmentProject",
#         "@id": "https://w3id.org/italia/data/PublicInvestmentProject/G31F22002180006",
#
#         "PRJ:uniqueProjectCodeValue": "G31F22002180006",
#         "PRJ:projectTitle": "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI",
#         "PRJ:projectTotalCost": 8262,
#         "PRJ:projectFunder": {
#             "@type":"COV:PublicOrganization",
#             "@id":"https://w3id.org/italia/data/PublicOrganization/83000370508",
#             "COV:hasCategory": {
#                 "@type": "COV:PublicOrganizationCategory",
#                 "@id":"https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO"
#             },
#             "COV:taxCode": "83000370508"
#         }
#         }
#
#     ]
# }

# %%
opencup_g = rdflib.Graph()
opencup_g.parse(data=opencup_json_ld,format="json-ld");

# %%
opencup_g.print()
# Out:
# @prefix COV: <https://w3id.org/italia/onto/COV/> .
# @prefix PRJ: <https://w3id.org/italia/onto/Project/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B11C22000490006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/82005730161> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 14 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 121992 ;
#     PRJ:uniqueProjectCodeValue "B11C22000490006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B11C22000940006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00271100224> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 9 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 47427 ;
#     PRJ:uniqueProjectCodeValue "B11C22000940006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B11F22000590006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/82005730161> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA CASOLINI 7*ENTRAMBI" ;
#     PRJ:projectTotalCost 155234 ;
#     PRJ:uniqueProjectCodeValue "B11F22000590006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B11F22001730006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/82005730161> ;
#     PRJ:projectTitle "PIATTAFORMA PAGOPA*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI" ;
#     PRJ:projectTotalCost
;
#     PRJ:projectTitle "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*NOTIFICHE VIOLAZIONI AL CODICE DELLA STRADA - NOTIFICHE VIOLAZIONI EXTRA CODICE DELLA STRADA" ;
#     PRJ:projectTotalCost 32589 ;
#     PRJ:uniqueProjectCodeValue "B51F22003690006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B51F22003720006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/80004870921> ;
#     PRJ:projectTitle "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*NOTIFICHE VIOLAZIONI CDS NOTIFICHE RISCOSSIONE TRIBUTI SENZA PAGAMENTO" ;
#     PRJ:projectTotalCost 59966 ;
#     PRJ:uniqueProjectCodeValue "B51F22003720006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B51F22005220006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00224340331> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)" ;
#     PRJ:projectTotalCost 20344 ;
#     PRJ:uniqueProjectCodeValue "B51F22005220006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B51F22005240006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/82005730161> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*PIATTAFORMA DIGITALE NAZIONALE DATI" ;
#     PRJ:projectTotalCost 20344 ;
#     PRJ:uniqueProjectCodeValue "B51F22005240006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B51F22006580006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/82002550398> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE API1, EROGAZIONE API2, EROGAZIONE API3" ;
#     PRJ:projectTotalCost 30515 ;
#     PRJ:uniqueProjectCodeValue "B51F22006580006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B51F22006590006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00218780393> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE API1" ;
#     PRJ:projectTotalCost 10172 ;
#     PRJ:uniqueProjectCodeValue "B51F22006590006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B51F22006750006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00297110389> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*N. 5 SERVIZI API" ;
#     PRJ:projectTotalCost 203435 ;
#     PRJ:uniqueProjectCodeValue "B51F22006750006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B51F22009410006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00088020086> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE API 1" ;
#     PRJ:projectTotalCost 10172 ;
#     PRJ:uniqueProjectCodeValue "B51F22009410006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B61C22000400006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/82001410164> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 14 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 121992 ;
#     PRJ:uniqueProjectCodeValue "B61C22000400006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B61F22000580006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00400660445> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA ROMA, 21*ENTRAMBI" ;
#     PRJ:projectTotalCost 79000 ;
#     PRJ:uniqueProjectCodeValue "B61F22000580006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B61F22001670006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/82001410164> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*TERRITORIO COMUNALE*RIGUARDA SITO COMUNALE E SERVIZI DIGITALI PER IL CITTADINO" ;
#     PRJ:projectTotalCost 155234 ;
#     PRJ:uniqueProjectCodeValue "B61F22001670006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B71C22000020001> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00297110389> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 21 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 1031574 ;
#     PRJ:uniqueProjectCodeValue "B71C22000020001" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B71F22000370001> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00297110389> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA COMUNE DI FERRARA*SITO COMUNALE E SERVIZI DIGITALI PER IL CITTADINO (ENTRAMBI)" ;
#     PRJ:projectTotalCost 457360 ;
#     PRJ:uniqueProjectCodeValue "B71F22000370001" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B71F22003180006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/82000950160> ;
#     PRJ:projectTitle "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*NOTIFICHE VIOLAZIONI AL CODICE DELLA STRADA E NOTIFICHE RISCOSSIONE TRIBUTI (CON PAGAMENTO)" ;
#     PRJ:projectTotalCost 32589 ;
#     PRJ:uniqueProjectCodeValue "B71F22003180006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B91C22001030006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/80095950152> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 13 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 77897 ;
#     PRJ:uniqueProjectCodeValue "B91C22001030006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B91F22000430006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00642650139> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*PIAZZA MONSIGNOR ZERBONI 1*ENTRAMBI" ;
#     PRJ:projectTotalCost 79922 ;
#     PRJ:uniqueProjectCodeValue "B91F22000430006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/B91F22003080006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/80095950152> ;
#     PRJ:projectTitle "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*010102P, 010201P, 010202N" ;
#     PRJ:projectTotalCost 23147 ;
#     PRJ:uniqueProjectCodeValue "B91F22003080006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C11C22000580006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00374900165> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*NUMERO 9 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 47427 ;
#     PRJ:uniqueProjectCodeValue "C11C22000580006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C11F22004700006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00720160167> ;
#     PRJ:projectTitle "PIATTAFORMA PAGOPA*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI" ;
#     PRJ:projectTotalCost 33423 ;
#     PRJ:uniqueProjectCodeValue "C11F22004700006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C11F22004710006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00720160167> ;
#     PRJ:projectTitle "ESTENSIONE DELLUTILIZZO DELLE PIATTAFORME NAZIONALI DI IDENTITÀ DIGITALE*TERRITORIO NAZIONALE*INTEGRAZIONE SPID E CIE" ;
#     PRJ:projectTotalCost 14000 ;
#     PRJ:uniqueProjectCodeValue "C11F22004710006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C11F22004740006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00165480096> ;
#     PRJ:projectTitle "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI" ;
#     PRJ:projectTotalCost 3402 ;
#     PRJ:uniqueProjectCodeValue "C11F22004740006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C11F22004760006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00165480096> ;
#     PRJ:projectTitle "PIATTAFORMA PAGOPA*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI" ;
#     PRJ:projectTotalCost 24280 ;
#     PRJ:uniqueProjectCodeValue "C11F22004760006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C17H22001560007> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/03611890157> ;
#     PRJ:projectTitle "ABILITAZIONE CLOUD*VIA IV NOVEMBRE 30*ABILITAZIONE CLOUD" ;
#     PRJ:projectTotalCost 77897 ;
#     PRJ:uniqueProjectCodeValue "C17H22001560007" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/
;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE API 1  EROGAZIONE API 2" ;
#     PRJ:projectTotalCost 20344 ;
#     PRJ:uniqueProjectCodeValue "C51F22004810006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C51F22005010006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00391260403> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*API REST" ;
#     PRJ:projectTotalCost 20344 ;
#     PRJ:uniqueProjectCodeValue "C51F22005010006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C51F22006570006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00231100512> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE N.2 API DA DEFINIRE" ;
#     PRJ:projectTotalCost 20344 ;
#     PRJ:uniqueProjectCodeValue "C51F22006570006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C51F22007070006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00257850396> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE API1, EROGAZIONE API2" ;
#     PRJ:projectTotalCost 20344 ;
#     PRJ:uniqueProjectCodeValue "C51F22007070006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C51F22007440006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00254640121> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE API 1" ;
#     PRJ:projectTotalCost 10172 ;
#     PRJ:uniqueProjectCodeValue "C51F22007440006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C51F22007530006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00108690470> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE N. 4 API" ;
#     PRJ:projectTotalCost 162748 ;
#     PRJ:uniqueProjectCodeValue "C51F22007530006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C51F22007770006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00385230545> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE NUMERO 3 API" ;
#     PRJ:projectTotalCost 30515 ;
#     PRJ:uniqueProjectCodeValue "C51F22007770006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C51F22008580006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00374900165> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*INTEROPERABILITA&#x27; DATI" ;
#     PRJ:projectTotalCost 10172 ;
#     PRJ:uniqueProjectCodeValue "C51F22008580006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C51F22008930006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00346630239> ;
#     PRJ:projectTitle "PIATTAFORMA DIGITALE NAZIONALE DATI (PDND)*TERRITORIO NAZIONALE*EROGAZIONE API 1 EROGAZIONE API 2" ;
#     PRJ:projectTotalCost 20344 ;
#     PRJ:uniqueProjectCodeValue "C51F22008930006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C61C22000150006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/80008790174> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 14 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 121992 ;
#     PRJ:uniqueProjectCodeValue "C61C22000150006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C61C22000460006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00223660127> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 14 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 121992 ;
#     PRJ:uniqueProjectCodeValue "C61C22000460006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C61C22000640006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00286650502> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 12 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 72828 ;
#     PRJ:uniqueProjectCodeValue "C61C22000640006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C61F22000090006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/80008790174> ;
#     PRJ:projectTitle "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI" ;
#     PRJ:projectTotalCost 16121 ;
#     PRJ:uniqueProjectCodeValue "C61F22000090006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C61F22000430006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/80008790174> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA PAOLO VI 17*IL SERVIZIO RIGUARDA ENTRAMBI, SIA IL SITO COMUNALE SIA I SERVIZI DIGITALI PER IL CITTADINO" ;
#     PRJ:projectTotalCost 155234 ;
#     PRJ:uniqueProjectCodeValue "C61F22000430006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C61F22000630006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00286650502> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA ROMA 37*SITO INTERNET COMUNALE E SERVIZI DIGITALI PER IL CITTADINO" ;
#     PRJ:projectTotalCost 79922 ;
#     PRJ:uniqueProjectCodeValue "C61F22000630006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C61F22000640006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/02613570429> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA CASTELLO 1*IL CONTRIBUTO RIGUARDA IL SITO COMUNALE E I SERVIZI DIGITALI PER IL CITTADINO" ;
#     PRJ:projectTotalCost 155234 ;
#     PRJ:uniqueProjectCodeValue "C61F22000640006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C61F22001090006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00354730392> ;
#     PRJ:projectTitle "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI" ;
#     PRJ:projectTotalCost 49455 ;
#     PRJ:uniqueProjectCodeValue "C61F22001090006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C61F22003250006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/80008790174> ;
#     PRJ:projectTitle "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*NOTIFICHE VIOLAZIONI CODICE DELLA STRADA - NOTIFICHE RISCOSSIONE TRIBUTI CON PAGAMENTO" ;
#     PRJ:projectTotalCost 32589 ;
#     PRJ:uniqueProjectCodeValue "C61F22003250006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C71C22000500006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/01329160483> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 14 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 252118 ;
#     PRJ:uniqueProjectCodeValue "C71C22000500006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C71F22003370006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/82002220620> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*TERRITORIO COMUNALE*SITO COMUNALE E SERVIZI DIGITALE PER IL CITTADINO" ;
#     PRJ:projectTotalCost 79922 ;
#     PRJ:uniqueProjectCodeValue "C71F22003370006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C81C22000320006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00385230545> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 14 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 252118 ;
#     PRJ:uniqueProjectCodeValue "C81C22000320006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C81C22005610006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00211890330> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 11 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 101208 ;
#     PRJ:uniqueProjectCodeValue "C81C22005610006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C81F22001690006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00385230545> ;
#     PRJ:projectTitle "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI" ;
#     PRJ:projectTotalCost 24024 ;
#     PRJ:uniqueProjectCodeValue "C81F22001690006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C81F22003780006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00385230545> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*TERRITORIO NAZIONALE*IL SITO COMUNALE (PACCHETTO CITTADINO INFORMATO) E SERVIZI DIGITALI  (PACCHETTO CITTADINO ATTIVO)" ;
#     PRJ:projectTotalCost 280932 ;
#     PRJ:uniqueProjectCodeValue "C81F22003780006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C91C22000190006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00304260409> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 21 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 1031574 ;
#     PRJ:uniqueProjectCodeValue "C91C22000190006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C91C22001470006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00852210178> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 14 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 121992 ;
#     PRJ:uniqueProjectCodeValue "C91C22001470006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C91C22004640006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/83000830758> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N.9 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 47427 ;
#     PRJ:uniqueProjectCodeValue "C91C22004640006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C91F22000870006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00313290389> ;
#     PRJ:projectTitle "PIATTAFORMA PAGOPA*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI" ;
#     PRJ:projectTotalCost 7891 ;
#     PRJ:uniqueProjectCodeValue "C91F22000870006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C91F22001290006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00313290389> ;
#     PRJ:projectTitle "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI" ;
#     PRJ:projectTotalCost 7533 ;
#     PRJ:uniqueProjectCodeValue "C91F22001290006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C91F22001670006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00313290389> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*PIAZZA UNITÀ D&#x27;ITALIA*ENTRAMBI" ;
#     PRJ:projectTotalCost 79922 ;
#     PRJ:uniqueProjectCodeValue "C91F22001670006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C91F22002070006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00073930950> ;
#     PRJ:projectTitle "ESTENSIONE DELLUTILIZZO DELLE PIATTAFORME NAZIONALI DI IDENTITÀ DIGITALE*TERRITORIO NAZIONALE*INTEGRAZIONE DI SPID E CIE" ;
#     PRJ:projectTotalCost 14000 ;
#     PRJ:uniqueProjectCodeValue "C91F22002070006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C91F22002080006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00073930950> ;
#     PRJ:projectTitle "APPLICAZIONE APP IO*TERRITORIO NAZIONALE*ATTIVAZIONE SERVIZI" ;
#     PRJ:projectTotalCost 1215 ;
#     PRJ:uniqueProjectCodeValue "C91F22002080006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C91F22003340006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00391260403> ;
#     PRJ:projectTitle "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*NOTIFICHE VIOLAZIONI AL CODICE DELLA STRADA; NOTIFICHE RISCOSSIONE E ENTRATE PATRIMONIALI (CON PAGAMENTO)" ;
#     PRJ:projectTotalCost 32589 ;
#     PRJ:uniqueProjectCodeValue "C91F22003340006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C91F22003760006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00391260403> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA REPUBBLICA 140*SITO COMUNALE E SERVIZI DIGITALI PER IL CITTADINO" ;
#     PRJ:projectTotalCost 155234 ;
#     PRJ:uniqueProjectCodeValue "C91F22003760006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C91F22003940006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00073930950> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA CARLO ALBERTO 33*ENTRAMBI RICHIEDERE L&#x27;ACCESSO AGLI ATTI RICHIEDERE ISCRIZIONE ALLA MENSA SCOLASTICA PRESENTARE DOMANDA PER BONUS ECONOMICI PAGARE TRIBUTI IMU SITO INTERNET (PACCHETTO CITTADINO INFORMATO)" ;
#     PRJ:projectTotalCost 79922 ;
#     PRJ:uniqueProjectCodeValue "C91F22003940006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C91F22004350006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00073930950> ;
#     PRJ:projectTitle "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*NOTIFICHE VIOLAZIONI AL CODICE DELLA STRADA - ATTIVITÀ DA AVVIARE  NOTIFICHE RISCOSSIONE TRIBUTI (CON PAGAMENTO)  -ATTIVITÀ DA AVVIARE" ;
#     PRJ:projectTotalCost 23147 ;
#     PRJ:uniqueProjectCodeValue "C91F22004350006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/C91F22004880006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/83000830758> ;
#     PRJ:projectTitle "ESTENSIONE DELLUTILIZZO DELLE PIATTAFORME NAZIONALI DI IDENTITÀ DIGITALE*TERRITORIO NAZIONALE*INTEGRAZIONE DI SPID E CIE" ;
#     PRJ:projectTotalCost 14000 ;
#     PRJ:uniqueProjectCodeValue "C91F22004880006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/D11C22001440006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00547910653> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE NEI SETTORI DEMOGRAFICI,ANAGRAFE, STATO CIVILE, ELETTORALE, PROTOCOLLO, ALBO PRETORIO, ECONOMATO, TRIBUTI MAGGIORI, GESTIONE ECONOMICA, CONTABILITÀ E RAGIONERIA" ;
#     PRJ:projectTotalCost 47427 ;
#     PRJ:uniqueProjectCodeValue "D11C22001440006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/D11C22001470006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/82005750904> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N.13 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 77897 ;
#     PRJ:uniqueProjectCodeValue "D11C22001470006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/D11F22000540006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00547910653> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*TERRITORIO COMUNALE*CANONE LAMPADE VOTIVE, PAGARE CONTRAVVENZIONI, TRIBUTI IMU E SITO INTERNET" ;
#     PRJ:projectTotalCost 67167 ;
#     PRJ:uniqueProjectCodeValue "D11F22000540006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/D11F22002730006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00547910653> ;
#     PRJ:projectTitle "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*SERVIZI E CITTADINANZA LOCALE. PIATTAFORMA NOTIFICHE DIGITALI" ;
#     PRJ:projectTotalCost 23147 ;
#     PRJ:uniqueProjectCodeValue "D11F22002730006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/D11F22003250006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/82005750904> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*VIA SANT&#x27;ANTONIO 2*SITO COMUNALE E SERVIZI DIGITALI PER IL CITTADINO" ;
#     PRJ:projectTotalCost 79922 ;
#     PRJ:uniqueProjectCodeValue "D11F22003250006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/D21C22001240006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00232420331> ;
#     PRJ:projectTitle "MIGRAZIONE AL CLOUD DEI SERVIZI DIGITALI DELL&#x27;AMMINISTRAZIONE*TERRITORIO COMUNALE*N. 14 SERVIZI DA MIGRARE" ;
#     PRJ:projectTotalCost 121992 ;
#     PRJ:uniqueProjectCodeValue "D21C22001240006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/D21F22000490006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00232420331> ;
#     PRJ:projectTitle "MIGLIORAMENTO DELLESPERIENZA DUSO DEL SITO E DEI SERVIZI DIGITALI PER IL CITTADINO - CITIZEN EXPERIENCE*COMUNE DI CASTEL SAN GIOVANNI*IL SERVIZIO RIGUARDA IL SITO COMUNALE E 4 SERVIZI DIGITALI PER IL CITTADINO" ;
#     PRJ:projectTotalCost 155234 ;
#     PRJ:uniqueProjectCodeValue "D21F22000490006" .
#
# <https://w3id.org/italia/data/PublicInvestmentProject/D21F22003360006> a PRJ:PublicInvestmentProject ;
#     PRJ:projectFunder <https://w3id.org/italia/data/PublicOrganization/00220600407> ;
#     PRJ:projectTitle "PIATTAFORMA NOTIFICHE DIGITALI (PND)*TERRITORIO COMUNALE*NOTIFICHE VIOLAZIONI AL CODICE DELLA STRADA, NOTIFICHE VIOLAZIONI EXTRA CODICE DELLA STRADA" ;
#     PRJ:projectTotalCost 59966 ;
# ...
#
# <https://w3id.org/italia/data/PublicOrganization/00577360241> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00577360241" .
#
# <https://w3id.org/italia/data/PublicOrganization/00624040135> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00624040135" .
#
# <https://w3id.org/italia/data/PublicOrganization/00662760362> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00662760362" .
#
# <https://w3id.org/italia/data/PublicOrganization/00720160167> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00720160167" .
#
# <https://w3id.org/italia/data/PublicOrganization/00720170166> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00720170166" .
#
# <https://w3id.org/italia/data/PublicOrganization/03614850158> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "03614850158" .
#
# <https://w3id.org/italia/data/PublicOrganization/80001830936> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "80001830936" .
#
# <https://w3id.org/italia/data/PublicOrganization/80004190593> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "80004190593" .
#
# <https://w3id.org/italia/data/PublicOrganization/80010610758> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "80010610758" .
#
# <https://w3id.org/italia/data/PublicOrganization/82002550398> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "82002550398" .
#
# <https://w3id.org/italia/data/PublicOrganization/85000870221> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "85000870221" .
#
# <https://w3id.org/italia/data/PublicOrganization/00073930950> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00073930950" .
#
# <https://w3id.org/italia/data/PublicOrganization/00168480242> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00168480242" .
#
# <https://w3id.org/italia/data/PublicOrganization/00172960361> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00172960361" .
#
# <https://w3id.org/italia/data/PublicOrganization/00179650221> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00179650221" .
#
# <https://w3id.org/italia/data/PublicOrganization/00229080338> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00229080338" .
#
# <https://w3id.org/italia/data/PublicOrganization/00240880161> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00240880161" .
#
# <https://w3id.org/italia/data/PublicOrganization/00311560361> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00311560361" .
#
# <https://w3id.org/italia/data/PublicOrganization/00314810367> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00314810367" .
#
# <https://w3id.org/italia/data/PublicOrganization/00341200095> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00341200095" .
#
# <https://w3id.org/italia/data/PublicOrganization/00351040423> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00351040423" .
#
# <https://w3id.org/italia/data/PublicOrganization/00385230545> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00385230545" .
#
# <https://w3id.org/italia/data/PublicOrganization/00493110928> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00493110928" .
#
# <https://w3id.org/italia/data/PublicOrganization/00533680658> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00533680658" .
#
# <https://w3id.org/italia/data/PublicOrganization/00534310248> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00534310248" .
#
# <https://w3id.org/italia/data/PublicOrganization/00547910653> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00547910653" .
#
# <https://w3id.org/italia/data/PublicOrganization/00686230368> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00686230368" .
#
# <https://w3id.org/italia/data/PublicOrganization/03396710125> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "03396710125" .
#
# <https://w3id.org/italia/data/PublicOrganization/80004000925> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "80004000925" .
#
# <https://w3id.org/italia/data/PublicOrganization/81000450643> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "81000450643" .
#
# <https://w3id.org/italia/data/PublicOrganization/82002850137> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "82002850137" .
#
# <https://w3id.org/italia/data/PublicOrganization/82002930285> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "82002930285" .
#
# <https://w3id.org/italia/data/PublicOrganization/84003870163> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "84003870163" .
#
# <https://w3id.org/italia/data/PublicOrganization/87003290159> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "87003290159" .
#
# <https://w3id.org/italia/data/PublicOrganization/91008330903> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "91008330903" .
#
# <https://w3id.org/italia/data/PublicOrganization/00115070336> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00115070336" .
#
# <https://w3id.org/italia/data/PublicOrganization/00223680125> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00223680125" .
#
# <https://w3id.org/italia/data/PublicOrganization/00252240262> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00252240262" .
#
# <https://w3id.org/italia/data/PublicOrganization/00268250230> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00268250230" .
#
# <https://w3id.org/italia/data/PublicOrganization/00297910796> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00297910796" .
#
# <https://w3id.org/italia/data/PublicOrganization/00606990174> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00606990174" .
#
# <https://w3id.org/italia/data/PublicOrganization/00631280138> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00631280138" .
#
# <https://w3id.org/italia/data/PublicOrganization/00834770158> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00834770158" .
#
# <https://w3id.org/italia/data/PublicOrganization/01495680157> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "01495680157" .
#
# <https://w3id.org/italia/data/PublicOrganization/80008790174> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "80008790174" .
#
# <https://w3id.org/italia/data/PublicOrganization/00254640121> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00254640121" .
#
# <https://w3id.org/italia/data/PublicOrganization/00263530123> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00263530123" .
#
# <https://w3id.org/italia/data/PublicOrganization/00339370272> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00339370272" .
#
# <https://w3id.org/italia/data/PublicOrganization/00602060139> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00602060139" .
#
# <https://w3id.org/italia/data/PublicOrganization/01639920154> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "01639920154" .
#
# <https://w3id.org/italia/data/PublicOrganization/80001190877> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "80001190877" .
#
# <https://w3id.org/italia/data/PublicOrganization/80007710264> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "80007710264" .
#
# <https://w3id.org/italia/data/PublicOrganization/80011350750> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "80011350750" .
#
# <https://w3id.org/italia/data/PublicOrganization/82001930385> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "82001930385" .
#
# <https://w3id.org/italia/data/PublicOrganization/82005730161> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "82005730161" .
#
# <https://w3id.org/italia/data/PublicOrganization/83000370508> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "83000370508" .
#
# <https://w3id.org/italia/data/PublicOrganization/00360140446> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00360140446" .
#
# <https://w3id.org/italia/data/PublicOrganization/00372530162> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00372530162" .
#
# <https://w3id.org/italia/data/PublicOrganization/00426650131> a COV:PublicOrganization ;
#     COV:hasCategory <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> ;
#     COV:taxCode "00426650131" .
#
# <https://w3id.org/italia/data/PublicOrganizationCategory/ENTI%20TERRITORIALI%20E%20DI%20AMMINISTRAZIONE%20DEL%20TERRITORIO> a COV:PublicOrganizationCategory .

# %%
query="""
SELECT (COUNT(DISTINCT ?CUP) as ?num_CUP) 
WHERE {
    # ?prj a PRJ:PublicInvestmentProject;
    PRJ:uniqueProjectCodeValue ?CUP
}
"""

res=opencup_g.query(query)

for row in res:
    print(row)
# Out:
# (rdflib.term.Literal('538', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),)

# %% [markdown]
# Come si vede, i CUP sono in numero inferiore, in quanto ve ne sono di duplicati all'interno del file.

# %% [markdown]
# Esempio di query: qual è il totale di costo dei progetti per ciascun ente?

# %%
query="""
SELECT ?funder (SUM(?totalCost) AS ?funderTotalCost)
WHERE {
    # ?prj a PRJ:PublicInvestmentProject;
    PRJ:projectFunder ?funder;
    PRJ:projectTotalCost ?totalCost.
}
GROUP BY ?funder
ORDER BY DESC(?funderTotalCost)
"""

res=opencup_g.query(query)

for row in res:
    print(row)
# Out:
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00339370272'), rdflib.term.Literal('7127677', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80015010723'), rdflib.term.Literal('4858680', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00297110389'), rdflib.term.Literal('1692369', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00080270838'), rdflib.term.Literal('1547897', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00229080338'), rdflib.term.Literal('1479027', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00304260409'), rdflib.term.Literal('1031574', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/91008330903'), rdflib.term.Literal('965270', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00360140446'), rdflib.term.Literal('752741', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00355870221'), rdflib.term.Literal('719758', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80001190877'), rdflib.term.Literal('679976', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00252240262'), rdflib.term.Literal('665866', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00834770158'), rdflib.term.Literal('643416', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00268250230'), rdflib.term.Literal('643416', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00221940364'), rdflib.term.Literal('616095', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00351040423'), rdflib.term.Literal('614609', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00152550208'), rdflib.term.Literal('600427', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00385230545'), rdflib.term.Literal('587589', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80000330656'), rdflib.term.Literal('585323', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00189800204'), rdflib.term.Literal('564156', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00516890241'), rdflib.term.Literal('554781', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01063800153'), rdflib.term.Literal('533050', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82002490264'), rdflib.term.Literal('527756', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00211160114'), rdflib.term.Literal('527308', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00097020598'), rdflib.term.Literal('516323', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00893240150'), rdflib.term.Literal('419124', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80007310263'), rdflib.term.Literal('419124', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00172960361'), rdflib.term.Literal('407813', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00372530162'), rdflib.term.Literal('404159', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/85001870188'), rdflib.term.Literal('402506', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00602060139'), rdflib.term.Literal('392385', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01639920154'), rdflib.term.Literal('376098', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00543170377'), rdflib.term.Literal('371413', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82005730161'), rdflib.term.Literal('371305', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00426650131'), rdflib.term.Literal('365895', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82001930385'), rdflib.term.Literal('357000', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/82002550398'), rdflib.term.Literal('355151', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80008790174'), rdflib.term.Literal('346280', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00263530123'), rdflib.term.Literal('344902', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00223680125'), rdflib.term.Literal('344159', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/01495680157'), rdflib.term.Literal('344159', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00606990174'), rdflib.term.Literal('343513', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/83005620154'), rdflib.term.Literal('342984', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/00115070336'), rdflib.term.Literal('341745', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/80004190593'), rdflib.term.Literal('333788', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('https://w3id.org/italia/data/PublicOrganization/81